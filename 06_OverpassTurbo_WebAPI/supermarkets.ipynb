# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
from pandas import json_normalize
import requests
import json
import folium

# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)
df.head(5)
# Out:
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.diet:organic tags.diet:seafood tags.brand:website  \
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN
#
#   tags.recycling:low_energy_bulbs tags.image tags.opening_hours:cafe  \
# 0                             NaN        NaN                     NaN
# 1                             NaN        NaN                     NaN
# 2                             NaN        NaN                     NaN
# 3                             NaN        NaN                     NaN
# 4                             NaN        NaN                     NaN
#
#   tags.currency:XBT tags.payment:lightning tags.payment:lightning_contactless  \
# 0               NaN                    NaN                                NaN
# 1               NaN                    NaN                                NaN
# 2               NaN                    NaN                                NaN
# 3               NaN                    NaN                                NaN
# 4               NaN                    NaN                                NaN
#
#   tags.payment:onchain
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 265 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Coop', 'Migros'])]
print(locations.head(5))

# Subsets
locations_coop = df[["lat", "lon", "tags.brand",
                     "tags.shop"]].loc[df["tags.brand"].isin(['Coop'])]
locations_migros = df[["lat", "lon", "tags.brand",
                       "tags.shop"]].loc[df["tags.brand"].isin(['Migros'])]

# Marker symbols
url_01 = 'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png'
url_02 = 'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-orange.png'

# Create map
map = folium.Map(location=[locations.lat.mean(),
                           locations.lon.mean()],
                 zoom_start=8,
                 control_scale=True)

# Add lat/lon of Coop supermarkets
for i in range(0, len(locations_coop)):
    folium.Marker(location=(locations_coop.iloc[i]['lat'],
                            locations_coop.iloc[i]['lon']),
                  popup=locations_coop.iloc[i]['tags.brand'],
                  icon=folium.features.CustomIcon(url_01, icon_size=(16, 28))).add_to(map)
    
# Add lat/lon of Migros supermarkets
for i in range(0, len(locations_migros)):
    folium.Marker(location=(locations_migros.iloc[i]['lat'],
                            locations_migros.iloc[i]['lon']),
                  popup=locations_migros.iloc[i]['tags.brand'],
                  icon=folium.features.CustomIcon(url_02, icon_size=(16, 28))).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_563ae1362c2eca2028cd79f52a5a7adb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_563ae1362c2eca2028cd79f52a5a7adb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_563ae1362c2eca2028cd79f52a5a7adb = L.map(
#                 &quot;map_563ae1362c2eca2028cd79f52a5a7adb&quot;,
#                 {
#                     center: [47.00839940984456, 7.995201227202072],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_563ae1362c2eca2028cd79f52a5a7adb);
#
#
#
#
#
#             var tile_layer_ef01416f6d02a80242128f0e11dddb56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef01416f6d02a80242128f0e11dddb56.addTo(map_563ae1362c2eca2028cd79f52a5a7adb);
#
#
#             var marker_6a543f2d09f04551524f2987b73d92dc = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_563ae1362c2eca2028cd79f52a5a7adb);
#
#
#         var custom_icon_03bcfcaaed360fa2ef27ec8210575687 = L.icon({&quot;iconSize&quot;: [16, 28], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_6a543f2d09f04551524f2987b73d92dc.setIcon(custom_icon_03bcfcaaed360fa2ef27ec8210575687);
#
#
#         var popup_4684ff6cfc16fa56bd6d033b32b95385 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0e4ecea78c000c5378e30d187725fb3 = $(`&lt;div id=&quot;html_b0e4ecea78c000c5378e30d187725fb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_4684ff6cfc16fa56bd6d033b32b95385.setContent(html_b0e4ecea78c000c5378e30d187725fb3);
#
#
#
#         marker_6a543f2d09f04551524f2987b73d92dc.bindPopup(popup_4684ff6cfc16fa56bd6d033b32b95385)
#         ;
#
#
#
#
#             var marker_628361ef74685bc963beed8ccf10283e = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_563ae1362c2eca2028cd79f52a5a7adb);
#
#
#         var custom_icon_3d555c8ce3be088034977756645c5376 = L.icon({&quot;iconSize&quot;: [16, 28], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_628361ef74685bc963beed8ccf10283e.setIcon(custom_icon_3d555c8ce3be088034977756645c5376);
#
#
#         var popup_af114af272ca27ed4138090417887fc7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3d36edc5668396818c360ad6d5dc480 = $(`&lt;div id=&quot;html_e3d36edc5668396818c360ad6d5dc480&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_af114af272ca27ed4138090417887fc7.setContent(html_e3d36edc5668396818c360ad6d5dc480);
#
#
#
#         marker_628361ef74685bc963beed8ccf10283e.bindPopup(popup_af114af272ca27ed4138090417887fc7)
#         ;
#
#
#
#
#             var marker_9f67d32c3f883932a1a6329b25602913 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}
#             ).addTo(map_563ae1362c2eca2028cd79f52a5a7adb);
#
#
#         var custom_icon_9459f1d332ceced8aaa51a08bfe45d14 = L.icon({&quot;iconSize&quot;: [16, 28], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_9f67d32c3f883932a1a6329b25602913.setIcon(custom_icon_9459f1d332ceced8aaa51a08bfe45d14);
#
#
#         var popup_f661dbc774c952d09dad5a1a42e805d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18c0557a00a4d09d8177ecd1b3b819e0 = $(`&lt;div id=&quot;html_18c0557a00a4d09d8177ecd1b3b819e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_f661dbc774c952d09dad5a1a42e805d2.setContent(html_18c0557a00a4d09d8177ecd1b3b819e0);
#
#
#
#         marker_9f67d32c3f883932a1a6329b25602913.bindPopup(popup_f661dbc774c952d09dad5a1a42e805d2)
#         ;
#
#
#
#
#             var marker_33d20c6e004dcda006ccb8eef5303c6d = L.marker(
#                 [47.241531, 8.7245301],
#                 {}
#             ).addTo(map_563ae1362c2eca2028cd79f52a5a7adb);
#
#
#         var custom_icon_ca05452917da57db58e82d8ad038b01e = L.icon({&quot;iconSize&quot;: [16, 28], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_33d20c6e004dcda006ccb8eef5303c6d.setIcon(custom_icon_ca05452917da57db58e82d8ad038b01e);
#
#
#         var popup_c7c8e5feee72f2817c78ffad26901346 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-10-15 11:42:55
# Python Version: 3.11.10
# -----------------------------------
