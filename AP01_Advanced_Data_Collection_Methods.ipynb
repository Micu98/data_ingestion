# %% [markdown]
# # Arbeitspaket (AP) 1: Advanced Data Collection Methods

# %% [markdown]
# ### Persönliche Angaben (bitte ergänzen)

# %% [markdown]
# <table>
#   <tr>
#     <td>Vorname:Micola</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Nachname:Vital</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Immatrikulationsnummer:20267217</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Modul:</td>
#     <td>Data Science</td>
#   </tr>
#   <tr>
#     <td>Prüfungsdatum / Raum / Zeit:</td>
#     <td>11.11.2024 / Raum: SF O3.54 / 8:00 – 11:45</td>
#   </tr>
#   <tr>
#     <td>Erlaubte Hilfsmittel:</td>
#     <td>w.MA.XX.DS.24HS (Data Science)<br>Open Book, Eigener Computer, Internet-Zugang</td>
#   </tr>
#   <tr>
#   <td>Nicht erlaubt:</td>
#   <td>Nicht erlaubt ist der Einsatz beliebiger Formen von generativer KI (z.B. Copilot, ChatGPT) <br> sowie beliebige Formen von Kommunikation oder Kollaboration mit anderen Menschen.</td>
# </tr>
# </table>

# %% [markdown]
# ## Bewertungskriterien
#
# ### <b style="color: gray;">(max. erreichbare Punkte: 48)</b>
#
# <table>
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Beschreibung</th>
#       <th>Punkteverteilung</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Code nicht lauffähig oder Ergebnisse nicht sinnvoll</td>
#       <td>Der Code enthält Fehler, die verhindern, dass er ausgeführt werden kann (z.B. Syntaxfehler) oder es werden Ergebnisse ausgegeben, welche nicht zur Fragestellung passen.</td>
#       <td>0 Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit gravierenden Mängeln</td>
#       <td>Der Code läuft, aber die Ergebnisse sind aufgrund wesentlicher Fehler unvollständig (z.B. grundlegende Fehler beim Einlesen der Daten). Nur geringer Fortschritt erkennbar.</td>
#       <td>25% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit mittleren Mängeln</td>
#       <td>Der Code läuft und liefert teilweise korrekte Ergebnisse, aber es gibt grössere Fehler (z.B. die Datentypen der eingelesenen Daten entsprechen nicht den Anforderungen gemäss Fragestellung). Die Ergebnisse sind nachvollziehbar, aber unvollständig oder ungenau.</td>
#       <td>50% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit minimalen Mängeln</td>
#       <td>Der Code läuft und liefert ein weitgehend korrektes Ergebnis, aber kleinere Fehler (z.B. Spaltenname falsch geschrieben, TimeStamp nicht korrekt formatiert) beeinträchtigen die Vollständigkeit des Ergebnisses.</td>
#       <td>75% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig und korrekt</td>
#       <td>Der Code läuft einwandfrei und liefert das korrekte Ergebnis ohne Mängel.</td>
#       <td>100% der max. erreichbaren Punkte</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Python Libraries und Settings

# %%
# Libraries
import os
import re
import json
import requests
import feedparser
import pandas as pd
import yfinance as yf
from zipfile import ZipFile
from bs4 import BeautifulSoup
from datetime import datetime
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from pandas import json_normalize
from lxml import html as lxml_html

from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_ingestion

# %% [markdown]
# ## <b>Vorbereitung (Dieser Teil wird <u>nicht</u> bewertet!)</b>

# %% [markdown]
# #### <b>1.) Starten Sie eine GitHub Codespaces Instanz auf Basis Ihres Forks des folgenden GitHub Repositories:</b>
#
# ##### GitHub-Repository: https://github.com/mario-gellrich-zhaw/data_ingestion

# %% [markdown]
# ## <b>Aufgaben (Dieser Teil wird bewertet!)</b>
# <b style="color:blue;">Hinweise zu den folgenden Aufgabenstellungen:</b>
# <ul style="color:blue;">
#   <li>Beachten Sie auch die zu jeder Aufgabenstellung zugehörenden Details zu Aufgabenstellung.</li>
#   <li>Lösen Sie jede Aufgabe mit Hilfe von Python Code. Integrieren Sie den Python Code in die Code-Zellen der jeweiligen Aufgabe.</li>
#   <li>Stellen Sie die Lösung(en) jeder Aufgabe ganz oder in Teilen (z.B. erste 5 Zeilen) eines DataFrames im Jupyter Notebook dar.</li>
#   <li>Wenn in den Aufgaben in Bezug auf das Datum vom 'aktuellen Tag' gesprochen wird, ist der Tag der Durchführung dieses Leistungsnachweises gemeint.</li>
# </ul>

# %% [markdown]
# #### <b>Aufgabe (1): Importieren Sie jedes der über den folgenden Codezellen angegebenen Files in ein eigenes pandas DataFrame.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die Files im Order 'Data'.
# - Berücksichtigen Sie die Ablage der Files beim Einlesen (z.B. Pfad zum Einlesen von 'BigmacPrice.csv' is: './Data/BigmacPrice.csv').
# - Zeigen Sie mit Hilfe eines geeigneten Python Befehls die Dimension des pandas DataFrames (Anzahl Zeilen und Spalten) im Jupyter Notebook an.
# - Stellen sie die erstellten DataFrames entweder ganz oder in Teilen (z.B. die ersten 5 Zeilen) im Jupyter Notebook dar.
#
# <b style="color: gray;">(max. erreichbare Punkte: 4)</b>

# %% [markdown]
# #### Importieren von 'BigmacPrice.csv'

# %%
# Import File 'BigmacPrice.csv' in ein Pandas DataFrame
data = pd.read_csv("BigmacPrice.csv", sep=";") #kontrollieren ob semikolon oder komma. default = UTF-8 mit komma

# Write data to csv
data.to_csv("BigmacPrice", sep=";")

# Anzeigen der Anzahl Zeilen und Spalten im DataFrame
print("Number of rows: ", data.shape[0])
print("Number of columns: ", data.shape[1])

# Anzeigen des DataFrames
# Print the header info of data (first five rows)
print(data.head(5))
# Out:
# Number of rows:  1946
# Number of columns:  1
#   date,"currency_code","name","local_price","dollar_ex","dollar_price"
# 0                 2000-04-01,ARS,Argentina,2.5,1,2.5
# 1               2000-04-01,AUD,Australia,2.59,1,2.59
# 2                  2000-04-01,BRL,Brazil,2.95,1,2.95
# 3                   2000-04-01,GBP,Britain,1.9,1,1.9
# 4                  2000-04-01,CAD,Canada,2.85,1,2.85

# %% [markdown]
# #### Importieren von 'CarData.xml'

# %%
# Import File 'CarData.xml'
data = pd.read_xml("CarData.xml")
print("------------------------")
print(data[["type","year"]])

# Anzeigen der Anzahl Zeilen und Spalten im DataFrame
print("Number of rows: ", data.shape[0])
print("Number of columns: ", data.shape[1])

# Anzeigen des DataFrames
print(data.head(5))
# Out:
# ------------------------
#             type  year
# 0          Sedan  1991
# 1          Wagon  1991
# 2            Van  2001
# 3            SUV  2011
# 4            SUV  2004
# ..           ...   ...
# 995          SUV  1996
# 996  Convertible  1997
# 997    Hatchback  1995
# 998  Convertible  2013
# 999          SUV  1999
#
# [1000 rows x 2 columns]
# Number of rows:  1000
# Number of columns:  10
#    car_id       make   type  year   hp  mileage     price  doors   color  \
# 0       1  Chevrolet  Sedan  1991  158    25040  17145.80      3  Orange
# 1       2        BMW  Wagon  1991  465   137449  29727.51      5     Red
# 2       3        Kia    Van  2001  189   202308  73312.00      4     Red
# 3       4     Toyota    SUV  2011  117   123661  22342.98      5   Black
# 4       5     Nissan    SUV  2004  339   256696  53094.74      5    Blue
#
#                          vin_number
# 0  A4BEEC1BAEAE4759B02FB952F5FDF7D0
# 1  3D154B9E846947C0BACB1729E4F3157A
# 2  E1AF7108C06E4501BFD5876FD733AB65
# 3  880B573230AA42488E2D97F065BB0681
# 4  138ECF9A0D8748F99F401942FD139103

# %% [markdown]
# #### Importieren von 'ChickenData.xlsx'

# %%
# Import File 'ChickenData.xlsx'
data = pd.read_excel("ChickenData.xlsx")

# Anzeigen der Anzahl Zeilen und Spalten im DataFrame
print("Number of rows: ", data.shape[0])
print("Number of columns: ", data.shape[1])

# Anzeigen des DataFrames
data.head(5)
# Out:
# Number of rows:  100
# Number of columns:  4
#    chicken_id       weight              breed  eggs_per_year
# 0           1  2435.836917  New Hampshire Red            158
# 1           2  2157.180545         Australorp            273
# 2           3  2558.418035  New Hampshire Red            153
# 3           4  2679.200608      Plymouth Rock            268
# 4           5  2556.855145         Australorp            360

# %% [markdown]
# #### Importieren von 'HotelData.json'

# %%
# Import File 'HotelData.json'
with open('HotelData.json', 'r') as f: # read mode ('r') and reads its content using json.load(), which parses the JSON data directly into a Python dictionary (data).
    data = json.load(f)
print(data)

# Read data to a data frame using the pandas library
data = pd.read_json("HotelData.json") # This line reads the same JSON file using pd.read_json() from the pandas library, directly converting it into a DataFrame (data).

# Anzeigen der Anzahl Zeilen und Spalten im DataFrame
print("Number of rows: ", data.shape[0])
print("Number of columns: ", data.shape[1])

# Anzeigen des DataFrames
print(data)
# Out:
# {'type': 'FeatureCollection', 'generator': 'overpass-turbo', 'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.', 'timestamp': '2024-10-27T16:52:02Z', 'features': [{'type': 'Feature', 'properties': {'@id': 'relation/3471358', 'addr:city': 'Islikon', 'addr:housenumber': '15', 'addr:postcode': '8546', 'addr:street': 'Hauptstrasse', 'building': 'yes', 'tourism': 'hotel', 'type': 'multipolygon', 'wikidata': 'Q1546090'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[8.8406937, 47.5449534], [8.840436, 47.5448787], [8.8402791, 47.5448513], [8.8403462, 47.5446609], [8.8404275, 47.544528], [8.8408797, 47.5447033], [8.8406937, 47.5449534]], [[8.8404313, 47.5447861], [8.8406428, 47.5448517], [8.8407234, 47.544747], [8.8404761, 47.5446652], [8.8404313, 47.5447861]]]}, 'id': 'relation/3471358'}, {'type': 'Feature', 'properties': {'@id': 'relation/12040185', 'addr:city': 'Opfikon', 'addr:housenumber': '116', 'addr:postcode': '8152', 'addr:street': 'Thurgauerstrasse', 'brand': 'Radisson', 'brand:wikidata': 'Q1751979', 'building': 'yes', 'building:levels': '7', 'name': 'Radisson', 'phone': '+41 44 561 60 50', 'tourism': 'hotel', 'type': 'multipolygon'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[8.5581772, 47.4218411], [8.5587343, 47.4216117], [8.5592506, 47.4221882], [8.5586616, 47.4224295], [8.5581772, 47.4218411]], [[8.5584216, 47.4219137], [8.5587116, 47.422238], [8.5589478, 47.4221413], [8.5586578, 47.421817], [8.5584216, 47.4219137]]]}, 'id': 'relation/12040185'}, {'type': 'Feature', 'properties': {'@id': 'relation/17686042', 'addr:city': 'Bad Zurzach', 'addr:country': 'CH', 'addr:housenumber': '25', 'addr:postcode': '5330', 'addr:street': 'Hauptstrasse', 'amenity': 'restaurant', 'building': 'yes', 'email': 'info@gasthof-zur-waag.ch', 'fax': '+41 56 249 33 54', 'internet_access': 'wlan', 'internet_access:fee': 'no', 'name': 'Gasthof zur Waag', 'phone': '+41 56 249 33 22', 'rooms': '21', 'smoking': 'outside', 'tourism': 'hotel', 'type': 'multipolygon', 'website': 'https://www.gasthof-zur-waag.ch/'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[8.2920868, 47.5858324], [8.2920921, 47.5858459], [8.2917979, 47.5858747], [8.2917521, 47.585697], [8.2922562, 47.5856433], [8.2923015, 47.5857955], [8.2920868, 47.5858324]], [[8.2918875, 47.5858058], [8.2920666, 47.5857772], [8.2920564, 47.5857342], [8.29187, 47.5857458], [8.2918875, 47.5858058]]]}, 'id': 'relation/17686042'}, {'type': 'Feature', 'properties': {'@id': 'way/22301937', 'addr:city': 'Winterthur', 'addr:country': 'CH', 'addr:housenumber': '4', 'addr:postcode': '8400', 'addr:street': 'Stadthausstrasse', 'building': 'apartments', 'building:levels': '4', 'check_date': '2024-04-11', 'name': 'Park Hotel', 'stars': '4', 'tourism': 'hotel', 'website': 'https://phwin.ch'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[8.7323259, 47.5011715], [8.7323302, 47.501092], [8.7323447, 47.5010923], [8.732345, 47.5010855], [8.7323248, 47.501085], [8.7323258, 47.5010679], [8.7323502, 47.5010685], [8.7323541, 47.5009972], [8.7325362, 47.5010017], [8.7325365, 47.5009963], [8.7325632, 47.5009969], [8.7325628, 47.5010046], [8.7326588, 47.501007], [8.7326584, 47.5010152], [8.7326829, 47.5010159], [8.7326848, 47.5010111], [8.7326879, 47.5010068], [8.7326924, 47.5010022], [8.7326964, 47.5009988], [8.7327025, 47.5009955], [8.7327095, 47.5009933], [8.7327178, 47.5009919], [8.7327258, 47.5009913], [8.7327344, 47.5009923], [8.7327427, 47.5009944], [8.7327497, 47.5009972], [8.7327559, 47.5010009], [8.7327598, 47.5010049], [8.7327632, 47.50101], [8.7327651, 47.5010143], [8.732767, 47.5010197], [8.7327923, 47.5010198], [8.7328054, 47.5008284], [8.7328606, 47.5008301], [8.732896, 47.5008312], [8.7328967, 47.5008175], [8.7329338, 47.5008184], [8.7329331, 47.5008323], [8.7329673, 47.5008334], [8.7330141, 47.5008348], [8.7329922, 47.5011579], [8.732816, 47.5011524], [8.7328148, 47.501174], [8.7325718, 47.501168], [8.7325713, 47.5011776 ...
# Number of rows:  456
# Number of columns:  5
#                   type       generator  \
# 0    FeatureCollection  overpass-turbo
# 1    FeatureCollection  overpass-turbo
# 2    FeatureCollection  overpass-turbo
# 3    FeatureCollection  overpass-turbo
# 4    FeatureCollection  overpass-turbo
# ..                 ...             ...
# 451  FeatureCollection  overpass-turbo
# 452  FeatureCollection  overpass-turbo
# 453  FeatureCollection  overpass-turbo
# 454  FeatureCollection  overpass-turbo
# 455  FeatureCollection  overpass-turbo
#
#                                              copyright  \
# 0    The data included in this document is from www...
# 1    The data included in this document is from www...
# 2    The data included in this document is from www...
# 3    The data included in this document is from www...
# 4    The data included in this document is from www...
# ..                                                 ...
# 451  The data included in this document is from www...
# 452  The data included in this document is from www...
# 453  The data included in this document is from www...
# 454  The data included in this document is from www...
# 455  The data included in this document is from www...
#
#                     timestamp  \
# 0   2024-10-27 16:52:02+00:00
# 1   2024-10-27 16:52:02+00:00
# 2   2024-10-27 16:52:02+00:00
# 3   2024-10-27 16:52:02+00:00
# 4   2024-10-27 16:52:02+00:00
# ..                        ...
# 451 2024-10-27 16:52:02+00:00
# 452 2024-10-27 16:52:02+00:00
# 453 2024-10-27 16:52:02+00:00
# 454 2024-10-27 16:52:02+00:00
# 455 2024-10-27 16:52:02+00:00
#
#                                               features
# 0    {'type': 'Feature', 'properties': {'@id': 'rel...
# 1    {'type': 'Feature', 'properties': {'@id': 'rel...
# 2    {'type': 'Feature', 'properties': {'@id': 'rel...
# 3    {'type': 'Feature', 'properties': {'@id': 'way...
# 4    {'type': 'Feature', 'properties': {'@id': 'way...
# ..                                                 ...
# 451  {'type': 'Feature', 'properties': {'@id': 'nod...
# 452  {'type': 'Feature', 'properties': {'@id': 'nod...
# 453  {'type': 'Feature', 'properties': {'@id': 'nod...
# 454  {'type': 'Feature', 'properties': {'@id': 'nod...
# 455  {'type': 'Feature', 'properties': {'@id': 'nod...
#
# [456 rows x 5 columns]

# %% [markdown]
# #### <b>Aufgabe (2): Extrahieren Sie aus dem File 'BookStore.html' die Preise der Bücher mit Hilfe eines geeigneten XPath.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden das HTML-File 'BookStore.html' im Order 'Data'.
# - Komplettieren Sie für das Lösen der Aufgabe den unfertigen XPath im folgenden Python Code.
# - Beachten Sie, dass nur ein einziger XPath für das Extrahieren aller Preise notwendig ist.
# - Stellen Sie die extrahierten Preise im Jupyter Notebook dar.<br><br>
# - Tipp: Für das Testen des XPath können Sie diesen Online XPath-Tester verwenden: http://xpather.com
#
# <b style="color: gray;">(max. erreichbare Punkte: 4)</b>

# %%
# Import File 'BookStore.html'
with open('BookStore.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Parsen des HTML-Contents
tree = lxml_html.fromstring(html_content)

# XPath zum Extrahieren der Buchpreise (bitte dort wo im XPath '...' steht, komplettieren)
try:
    prices = tree.xpath("//div[@class='book']/p[2]/text()")
except:
    prices = [] # gibt eine leere Liste aus, falls der XPath nicht korrekt ist

# Anzeigen der extrahierten Buchpreise
print("Extracted Book Prices:", prices)
# Out:
# Extracted Book Prices: ['$10.99', '$9.99', '$12.99']

# %% [markdown]
# #### <b>Aufgabe (3): Erstellen Sie ein pandas DataFrame mit den Daten aus der folgenden Tabelle (1), und speichern Sie dieses als XML-File ab.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Speichern Sie das erstellte XML-File als 'SmartphoneData.xml' im Ordner 'Data'.
# - Stellen Sie das erstellte DataFrame im Jupyter Notebook dar.<br>
#
# Tipp: Beim Erstellen eines Dataframes wird typischerweise zuerst ein Python dictionary erstellt und dieses anschliessend in ein DataFrame umgewandelt.
#
# Tabelle (1): Smartphone Data
#
# | Marke       | Modell       | Baujahr | Farbe   | Preis   |
# |-------------|--------------|---------|---------|---------|
# | Apple       | iPhone 12    | 2020    | Schwarz | 799     |
# | Samsung     | Galaxy S21   | 2021    | Weiß    | 999     |
# | Google      | Pixel 5      | 2020    | Grün    | 699     |
# | OnePlus     | 8 Pro        | 2020    | Blau    | 899     |
#
# <b style="color: gray;">(max. erreichbare Punkte: 4)</b>

# %%
# Erstellen des DataFrames aus der gegebenen Tabelle


# Abspeichern des DataFrames als XML-Datei


# Anzeigen des DataFrames

# %% [markdown]
# #### <b>Aufgabe (4): Erstellen Sie ein ZIP-File aus den folgenden genannten Files, und speichern Sie dieses im Order 'Data' ab.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Verwenden Sie die folgenden Files aus dem Ordner 'Data' als Input für das ZIP-File:
#   - BigmacPrice.csv
#   - BookStore.html
#   - CarData.xml
#   - ChickenData.xlsx
#   - HotelData.json
# - Speichern Sie das ZIP-File als 'MyData.zip' im Ordner 'Data' ab.
#
# <b style="color: gray;">(max. erreichbare Punkte: 4)</b>

# %%
# Erstellen eines leeren Zip-Archivs
zipObj = ZipFile('MyData.zip', 'w')

# Hinzufügen der Dateien zum Zip-Archiv
zipObj.write('BigmacPrice.csv')
zipObj.write('BookStore.html')
zipObj.write('CarData.xml')
zipObj.write('ChickenData.xlsx')
zipObj.write('HotelData.json')

# Schliessen des Zip-Archivs
zipObj.close()

# %% [markdown]
# #### <b>Aufgabe (5): Beziehen Sie Daten zu Cryptowährungen mit Hilfe der Coingecko Web API.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Verwenden Sie die folgenden Bezeichnungen (Ids) der Cryptowährungen für die Server-Anfragen: <b>binancecoin, cardano, polkadot, solana</b>.
# - Fragen Sie folgende Daten ab (Währung = EUR):
#   - Markkapitalisierung (include_market_cap='true')
#   - 24 Stunden Volumen (include_24hr_vol='true')
#   - 24 Stunden Veränderung (include_24hr_change='true')
#   - Datum des letzten Updates (include_last_updated_at='true')
# - Wandeln Sie die Daten in ein DataFrame um und stellen Sie dieses im Jupyter Notebook dar.<br><br>
#
# - Tipp: data = cg.get_price() speichert die Daten in ein Python dictionary. Dieses kann mit df = pd.DataFrame(data) in ein DataFrame umgewandelt werden.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Beziehen der Daten mit Hilfe der Coingecko Web API
cg.get_price(ids=['binancecoin', 'cardano', 'polkadot', 'solana'], vs_currencies='eur')

# Pass optional parameters as defined in the API doc (https://www.coingecko.com/api/docs/v3)
data = cg.get_price( ids='binancecoin, cardano, polkadot, solana', 
                     vs_currencies='eur', 
                     include_market_cap='true', 
                     include_24hr_vol='true', 
                     include_24hr_change='true', 
                     include_last_updated_at='true')


# Speichern der Daten in einem pandas DataFrame
df = pd.DataFrame(data)

# Anzeigen des DataFrames
df
# Out:
#                   binancecoin       cardano      polkadot        solana
# eur              5.739600e+02  5.310870e-01  4.700000e+00  1.933200e+02
# eur_market_cap   8.381243e+10  1.902606e+10  6.752928e+09  9.127543e+10
# eur_24h_vol      2.355213e+09  5.050635e+09  1.210911e+09  1.023504e+10
# eur_24h_change  -2.691995e+00 -1.296044e+00  2.623230e+00  8.564110e-01
# last_updated_at  1.731310e+09  1.731310e+09  1.731310e+09  1.731310e+09

# %% [markdown]
# #### <b>Aufgabe (6): Beziehen Sie Börsendaten zur Tesla-Aktie mit Hilfe der Yahoo-Finance Web API.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Die Tesla Aktie hat das Kürzel TSLA.
# - Definieren Sie '2023-01-01' als Startdatum für die Abfrage der Börsendaten.
# - Verwenden Sie die Python Library 'datetime' für die Erstellung des Enddatums (aktueller Tag).
# - Speichern Sie die Börsendaten in einem pandas DataFrame ab.
# - Stellen Sie die Daten der fünf aktuellsten Börsentage im Jupyter Notebook dar.<br><br>
#
# - Hinweis: Die neusten Daten aus der Yahoo-Finance Web API sind jeweils vom Vortag.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Erstellen eines Datumsobjekts mit dem aktuellen Datum und der aktuellen Uhrzeit
today = datetime.now().strftime("%Y-%m-%d")
print('Today is:', today)
 

# Beziehen der Tesla Aktienkurse von Yahoo Finance
data = yf.download('TSLA', start = "2023-01-01", end = today, progress=False)
data.tail()

# Anzeigen der Anzahl Zeilen und Spalten im DataFrame
print("Number of rows: ", data.shape[0])
print("Number of columns: ", data.shape[1])

# Anzeigen des DataFrames mit den Daten der fünf aktuellsten Börsentage
data.head(5)
# Out:
# Today is: 2024-11-11
# Number of rows:  467
# Number of columns:  6
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  118.470001  118.800003  104.639999  108.099998  108.099998
# 2023-01-04  109.110001  114.589996  107.519997  113.639999  113.639999
# 2023-01-05  110.510002  111.750000  107.160004  110.339996  110.339996
# 2023-01-06  103.000000  114.389999  101.809998  113.059998  113.059998
# 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
#
#                Volume
# Date
# 2023-01-03  231402800
# 2023-01-04  180389000
# 2023-01-05  157986300
# 2023-01-06  220911100
# 2023-01-09  190284000

# %% [markdown]
# #### <b>Aufgabe (7): Beziehen Sie mit Hilfe der Overpass Turbo Web API Daten zu den Tankstellen in der Schweiz.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Tankstellen sind mit dem key:value Paar "amenity"="fuel" in der OpenStreetMap Map-Feature Übersicht angegeben.
# - Speichern Sie die Daten in einem File 'petrol_station.json' im Order 'Data' ab.
# - Lesen Sie die Daten zusätzlich in ein pandas DataFrame und zeigen Sie dieses ganz oder in Teilen (z.B. erste 5 Zeilen) an.<br><br>
# - Tipp: Auf der Webseite: https://overpass-turbo.eu können Sie Overpass Turbo Abfragen testen.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo Abfrage-String
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["amenity"="fuel"](area); 
        out;"""

# Web API Anfrage
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Speichern der Daten in einer JSON-Datei
with open('petrol_station.json', 'w') as json_file:
    json.dump(data, json_file)

# Speichern der Daten in einem Pandas DataFrame und Anzeigen des DataFrames
df = json_normalize(data)
df.head(5)
# Out:
#    type       id        lat       lon tags.amenity tags.brand  \
# 0  node   734402  46.690599  7.668189         fuel        Eni
# 1  node  1228781  46.878598  7.542326         fuel         BP
# 2  node  5702030  46.680546  7.827412         fuel     Migrol
# 3  node  5702071  46.683415  7.844559         fuel       Avia
# 4  node  8082505  46.683817  7.664427         fuel        NaN
#
#   tags.brand:wikidata tags.name tags.fuel:diesel tags.operator  ...  \
# 0             Q565594       Eni              NaN           NaN  ...
# 1                 NaN       NaN              yes            BP  ...
# 2            Q1747771    Migrol              NaN           NaN  ...
# 3             Q300147      Avia              NaN          Avia  ...
# 4                 NaN       NaN              NaN           NaN  ...
#
#   tags.construction tags.dog tags.payment:hubrol_card tags.fuel:lng  \
# 0               NaN      NaN                      NaN           NaN
# 1               NaN      NaN                      NaN           NaN
# 2               NaN      NaN                      NaN           NaN
# 3               NaN      NaN                      NaN           NaN
# 4               NaN      NaN                      NaN           NaN
#
#   tags.fuel:petrol tags.outdoor_seating tags.operator:wikidata  \
# 0              NaN                  NaN                    NaN
# 1              NaN                  NaN                    NaN
# 2              NaN                  NaN                    NaN
# 3              NaN                  NaN                    NaN
# 4              NaN                  NaN                    NaN
#
#   tags.maxheight:signed tags.currency:others tags.payment:euroshell
# 0                   NaN                  NaN                    NaN
# 1                   NaN                  NaN                    NaN
# 2                   NaN                  NaN                    NaN
# 3                   NaN                  NaN                    NaN
# 4                   NaN                  NaN                    NaN
#
# [5 rows x 196 columns]

# %% [markdown]
# #### <b>Aufgabe (8): Beziehen und Visualisieren Sie die aktuellen News-Feed (RSS-Feed) Daten der New York Times.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Verwenden Sie diese URL zum RSS-Feed der New York Times Welt-Nachrichten: https://rss.nytimes.com/services/xml/rss/nyt/World.xml
# - Beziehen Sie die RSS-Feeds und extrahieren sie die Titel der Artikel aus den RSS-Feed Einträgen.
# - Zeigen Sie die Titel der RSS-Feed Einträge im Jupyter Notebook an.
# - Erstellen Sie eine Graphik mit einer Word-Cloud der Titel der RSS-Feed Einträge und stellen Sie diese im Jupyter Notebook dar.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Parsen des RSS-News Feed von der New York Times World News Webseite
feed = feedparser.parse("https://rss.nytimes.com/services/xml/rss/nyt/World.xml")

# Extrahieren der RSS-Feed Einträge
feed_entries = feed.entries

# Initialisieren des WordCloud-Texts
wordcloud_text = ""

# Loop für Anzeige des Artikel-Titels
print("Article Titles:")
for entry in feed.entries:

    article_title = entry.title

# Generieren der WordCloud
    wordcloud_text += f"{article_title} "

# Anzeigen der WordCloud
    print(f"{article_title}")


    # Change and format output
    print(f"{article_title}")
    # print(f"{article_title}[{article_link}]")
    # print(f"Published at {article_published_at}")

# Generate the word cloud from the newspapper most used words
wordcloud = WordCloud(width=800, 
                      height=400, 
                      background_color='black').generate(wordcloud_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axes
plt.show()
# Out:
# Article Titles:
# How Attacks on Israeli Soccer Fans in Amsterdam Unfolded
# How Attacks on Israeli Soccer Fans in Amsterdam Unfolded
# Taiwan Sees a Higher Price for U.S. Support as Trump Returns to Power
# Taiwan Sees a Higher Price for U.S. Support as Trump Returns to Power
# Saudi Arabia Hosts a Tennis Final Won by Coco Gauff
# Saudi Arabia Hosts a Tennis Final Won by Coco Gauff
# Trump’s Presidency Could Spell a Lonely and Dangerous Stretch for Europe
# Trump’s Presidency Could Spell a Lonely and Dangerous Stretch for Europe
# Israeli Strike in Gaza Kills Over 30 Palestinians, Emergency Services Say
# Israeli Strike in Gaza Kills Over 30 Palestinians, Emergency Services Say
# Palestinians Try to Sway Trump, Reaching Out to Tiffany Trump’s Relative
# Palestinians Try to Sway Trump, Reaching Out to Tiffany Trump’s Relative
# Israeli Strike Kills 23 People North of Beirut, Lebanon Says
# Israeli Strike Kills 23 People North of Beirut, Lebanon Says
# Russia Says It Shot Down Waves of Ukrainian Drones Above Moscow
# Russia Says It Shot Down Waves of Ukrainian Drones Above Moscow
# Han Dongfang, Once China’s ‘Worst Nightmare,’ Refuses to Back Down
# Han Dongfang, Once China’s ‘Worst Nightmare,’ Refuses to Back Down
# 50,000 Russian and North Korean Troops Mass Ahead of Attack, U.S. Says
# 50,000 Russian and North Korean Troops Mass Ahead of Attack, U.S. Says
# How World Leaders Are Prepping for a Second Trump Presidency
# How World Leaders Are Prepping for a Second Trump Presidency
# How Ukraine’s Widows Are Shouldering Their Grief
# How Ukraine’s Widows Are Shouldering Their Grief
# Trump’s Election Has Migrants Rethinking Plans to Head to the U.S.
# Trump’s Election Has Migrants Rethinking Plans to Head to the U.S.
# Is a ‘Green’ Revolution Poisoning India’s Capital?
# Is a ‘Green’ Revolution Poisoning India’s Capital?
# Why Did Tens of Thousands of Chinese Students Go on Night Bike Rides?
# Why Did Tens of Thousands of Chinese Students Go on Night Bike Rides?
# Monday Briefing
# Monday Briefing
# Will Trump Rekindle a Bromance With Kim Jong-un? South Koreans Worry.
# Will Trump Rekindle a Bromance With Kim Jong-un? South Koreans Worry.
# Why Is COP29 Being Held in Baku, Azerbaijan?
# Why Is COP29 Being Held in Baku, Azerbaijan?
# COP29 talks open in Baku in the shadow of Trump’s election
# COP29 talks open in Baku in the shadow of Trump’s election
# Monday Briefing: Russian and North Korean Troops Assemble
# Monday Briefing: Russian and North Korean Troops Assemble
# Paul Stephenson, 87, Dies; Advanced Britain’s Civil Rights Movement
# Paul Stephenson, 87, Dies; Advanced Britain’s Civil Rights Movement
# Trump Should Not Let Putin Claim Victory in Ukraine, Says NATO Official
# Trump Should Not Let Putin Claim Victory in Ukraine, Says NATO Official
# Baltazar Ushca, Who Kept Andean Ice Harvesting Alive, Dies at 80
# Baltazar Ushca, Who Kept Andean Ice Harvesting Alive, Dies at 80
# Trevor Sorbie, Creator of the Dorothy Hamill ‘Wedge’ Cut, Dies at 75
# Trevor Sorbie, Creator of the Dorothy Hamill ‘Wedge’ Cut, Dies at 75
# Qatar Pauses Role as Israel-Hamas Mediator in Gaza Cease-Fire Talks
# Qatar Pauses Role as Israel-Hamas Mediator in Gaza Cease-Fire Talks
# Amsterdam Bars Protests After Antisemitic Attacks on Israeli Soccer Fans
# Amsterdam Bars Protests After Antisemitic Attacks on Israeli Soccer Fans
# U.N.-Backed Panel Urges ‘Immediate Action’ in Gaza to Avert Famine
# U.N.-Backed Panel Urges ‘Immediate Action’ in Gaza to Avert Famine
# Playing Favorites
# Playing Favorites
# Canada Sends Mixed Signals With TikTok Shutdown Order
# Canada Sends Mixed Signals With TikTok Shutdown Order
# Suicide Bombing in Pakistan Leaves Dozens Dead or Wounded at Quetta Railway Station
# Suicide Bombing in Pakistan Leaves Dozens Dead or Wounded at Quetta Railway Station
# Russia Sentences 2 Soldiers Over Killing of Ukrainian Family
# Russia Sentences 2 Soldiers Over Killing of Ukrainian Family
# How We Found the Dangers Threatening Delhi’s ‘Green’ Energy Future
# How We Found the Dangers Threatening Delhi’s ‘Green’ Energy Future
# A Messy Problem in Orderly Singapore: Keeping Track of Cats
# A Messy Problem in Orderly Singapore: Keeping Track of Cats
# Gazans Are Living Through a Yearlong Blackout
# Gazans Are Living Through a Yearlong Blackout
# The Long Global Trail of Resentment Behind Trump’s Resurrection
# The Long Global Trail of Resentment Behind Trump’s Resurrection
# Who Is Viktor Orban, Hungary’s Authoritarian Leader and Friend of Trump?
# Who Is Viktor Orban, Hungary’s Authoritarian Leader and Friend of Trump?
# What to Know About the Attacks on Israeli Soccer Fans in Amsterdam
# What to Know About the Attacks on Israeli Soccer Fans in Amsterdam
# America’s Wobbly Democracy
# America’s Wobbly Democracy
# Elon Musk Joined Trump’s Call With Zelensky
# Elon Musk Joined Trump’s Call With Zelensky
# Playing Out a Dream, a Long, Long Way From Home
# Playing Out a Dream, a Long, Long Way From Home
# Party Whose Leader Is Known for Antisemitism to Join Lithuanian Government
# Party Whose Leader Is Known for Antisemitism to Join Lithuanian Government
# Notre-Dame’s Bells Ring Together for First Time Since Fire
# Notre-Dame’s Bells Ring Together for First Time Since Fire
# Russia Hits Ukraine with Drones, Missiles Overnight
# Russia Hits Ukraine with Drones, Missiles Overnight
# With Trump Tariffs Looming, Businesses Try to ‘Run From a Moving Target’
# With Trump Tariffs Looming, Businesses Try to ‘Run From a Moving Target’
# Gazan Rescue Service Has Stopped Operating in the North
# Gazan Rescue Service Has Stopped Operating in the North
# India Scraps Import Ban on Salman Rushdie’s ‘Satanic Verses’
# India Scraps Import Ban on Salman Rushdie’s ‘Satanic Verses’
# How My War Came Home
# How My War Came Home
# Hungary’s Viktor Orban and European Far-Right Leaders Welcome Trump’s Return
# Hungary’s Viktor Orban and European Far-Right Leaders Welcome Trump’s Return
# Will Musk Influence Trump on Climate Change and Electric Vehicles?
# Will Musk Influence Trump on Climate Change and Electric Vehicles?
# Antisemitic Attacks Prompt Emergency Flights for Israeli Soccer Fans
# Antisemitic Attacks Prompt Emergency Flights for Israeli Soccer Fans
# Friday Briefing
# Friday Briefing
# Ireland to Hold Snap General Election: What to Know
# Ireland to Hold Snap General Election: What to Know
# Argentina Drove Down Teen Pregnancy. Then Came Javier Milei.
# Argentina Drove Down Teen Pregnancy. Then Came Javier Milei.
# Prince William: Past Year Hardest of Life, After Kate and Charles’ Cancer Diagnoses
# Prince William: Past Year Hardest of Life, After Kate and Charles’ Cancer Diagnoses
# Friday Briefing: Biden promises a peaceful transition
# Friday Briefing: Biden promises a peaceful transition
# Interpol Tightens Oversight After Autocrats Target Its Databases
# Interpol Tightens Oversight After Autocrats Target Its Databases
# Australia Moves to Ban Young Teens From Social Media
# Australia Moves to Ban Young Teens From Social Media
# European Leaders Meet Amid Trump Victory and Global Uncertainty
# European Leaders Meet Amid Trump Victory and Global Uncertainty

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('IP Address:', socket.gethostbyname(socket.gethostname()))
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-11-11 07:48:30
# Python Version: 3.11.10
# IP Address: 127.0.0.1
# -----------------------------------
