# %% [markdown]
# # Getting Text data from RSS-Feeds

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import feedparser
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(f'Current working directory: {os.getcwd()}')
# Out:
# Current working directory: /workspaces/data_ingestion/07_RSS_Feeds

# %% [markdown]
# ## Parse the RSS feed

# %%
# RSS feeds from NZZ website
#feed = feedparser.parse("https://www.nzz.ch/startseite.rss") #andere Zeitungen suchen und einfügen
feed = feedparser.parse("https://www.luzernerzeitung.ch/zentralschweiz/luzern.rss")

# %% [markdown]
# ## Extract the data

# %%
# Get data from RSS feeds
feed_entries = feed.entries

# Initialize an empty string to store the text
wordcloud_text = ""

# Show first RSS-feeds
print("Article Titles:")
for entry in feed.entries:

    article_title = entry.title
    article_link = entry.link
    article_published_at = entry.published
    article_published_at_parsed = entry.published_parsed

    # Append the title to the wordcloud_text
    wordcloud_text += f"{article_title} "

    # Change and format output
    print(f"{article_title}")
    # print(f"{article_title}[{article_link}]")
    # print(f"Published at {article_published_at}")
# Out:
# Article Titles:
# Zwischen Schweizer Fussballliga und Behörden herrscht Eiszeit: Wie verknorzt ist die Lage in Luzern, Frau Fanaj?
# Asylunterkunft schliesst wegen «unschönen Situationen» mit Wohnbevölkerung
# Höhere Defizite sollen möglich sein: Krienser Stadtrat will Finanzregeln wieder lockern
# «Journalismus ist ein Knochenjob»: MAZ-Chefin über die Zukunft der Medien
# Frau von Bus mitgeschleift und schwer verletzt
# «Heiri» holt Lehm für Körbliger Backsteine: So wird der Rohstoff vom Abbaugebiet zur Ziegelei gefahren
# Määs egalisiert Besucherrekord – kommt die Herbstmesse auf die Unesco-Liste für Weltkulturerbe?
# Packender Tanz: Die Finsternis der zerstörten Natur wird zum Sonnenaufgang
# Markus Achermann ist neuer Dominus der Gesellschaft Fidelitas Lucernensis
# Stefan Wülser ist Gallivater 2025
# Ab in die Berge: Warum mehr Jugendliche wandern gehen sollten
# Wenn der «Bitte nicht stören»-Modus zu gut funktioniert
# Protest gegen Menschenhandel auch in Luzern
# Im Verkehrshaus messen sich Lehrlinge für einen guten Zweck
# Feuerwehr auf dem Dampfschiff Stadt Luzern: Zwischenhalt in Brunnen wegen Rauchalarm
# Das Theaterprojekt wurde verfeinert und gut vorgestellt – nun spreche das Volk!
# Luzerner SVP-Bauern fühlen sich von der Mitte übergangen
# Nur noch zwei traditionelle Metzgereien in der Stadt Luzern – mit diesen Herausforderungen kämpft die Branche
# LUKB: Ex-Finma-Mann nimmt die Risiken für den Kanton Luzern unter die Lupe
# «Fangewalt gilt es ein für alle Mal zu stoppen» – darum weibelt die Politik für die umstrittenen personalisierten Tickets für Fussballspiele
# Teure Bauwerke für Tiere? Warum Wildtierüberführungen ihren Preis wert sind
# Mit Mitte 40 hat sie nochmals die Schulbank gedrückt – mit Erfolg
# Zwischen Rom und Luzern ist es schon seit 150 Jahren kompliziert
# GLP-Kantonsrätin warnt vor Kollaps: «Das Netz der Freiwilligenarbeit droht zusammenzubrechen»
# Unternehmer-Machos haben Lust auf junge Frauen und zerstören ihre eigene Familie
# Direkt aus den Parteien: Das sind die Themen der Fraktionen
# Stefan «Büsché» Bucher ist neuer Präsident der Maskenliebhaber-Gesellschaft der Stadt Luzern
# Luzerner Regierung hat Verkehrssteuern nochmals berechnet: Besitzer von beliebten Autos werden neu bestraft
# Beatrice Egli wagt etwas ganz Neues – und erklärt zudem, was Dieter Bohlen damals in ihr gesehen hat
# «Ich sammle Leben, nicht Jahre»: Wie Krebspatientin Michèle Bowley ihr Schicksal annimmt
# Warum die Glocken der Pauluskirche erst falsch läuteten – und jetzt gänzlich verstummt sind
# «Hello Dolly» kehrt nach Meggen zurück

# %% [markdown]
# ## Generate a WordCloud

# %%
# Generate the word cloud from the newspapper most used words
wordcloud = WordCloud(width=800, 
                      height=400, 
                      background_color='black').generate(wordcloud_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-10-15 11:47:28
# Python Version: 3.11.10
# -----------------------------------
